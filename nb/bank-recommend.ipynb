# %% [markdown]
# ### Import Dependencies (Pandas)

# %%
import pandas as pd
import time

# %% [markdown]
# ### Load Data

# %%
begin = time.time()
df = pd.read_csv("E:/workspace/bank-data-challenge/data/Consumer_Complaints.csv",index_col=False)
print(f"Elapsed: {round(time.time()-begin, 2)} sec")
# Out:
# Elapsed: 7.42 sec

# %% [markdown]
# ### Profile Data

# %%
df.head(10)
# Out:
#   Date received                                            Product  \
# 0    08/09/2015                                   Credit reporting
# 1    01/29/2019  Credit reporting, credit repair services, or o...
# 2    10/13/2019                                    Debt collection
# 3    08/19/2015                                           Mortgage
# 4    03/04/2016                                        Credit card
# 5    03/18/2013                                           Mortgage
# 6    12/21/2011                                           Mortgage
# 7    10/24/2018  Credit reporting, credit repair services, or o...
# 8    03/03/2018  Credit reporting, credit repair services, or o...
# 9    01/02/2019                                    Debt collection
#
#                               Sub-product  \
# 0                                     NaN
# 1                        Credit reporting
# 2                           I do not know
# 3  Conventional adjustable mortgage (ARM)
# 4                                     NaN
# 5                          Other mortgage
# 6             Conventional fixed mortgage
# 7                        Credit reporting
# 8                        Credit reporting
# 9                           I do not know
#
#                                                Issue  \
# 0             Incorrect information on credit report
# 1  Problem with a credit reporting company's inve...
# 2                  Attempts to collect debt not owed
# 3           Loan servicing, payments, escrow account
# 4                                   Billing disputes
# 5           Loan modification,collection,foreclosure
# 6           Loan modification,collection,foreclosure
# 7               Incorrect information on your report
# 8               Incorrect information on your report
# 9                  Attempts to collect debt not owed
#
#                                            Sub-issue  \
# 0                            Information is not mine
# 1  Was not notified of investigation status or re...
# 2                  Debt was result of identity theft
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                           Account status incorrect
# 8                Information belongs to someone else
# 9                  Debt was result of identity theft
#
#                         Consumer complaint narrative  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  I am dissatisfied with the current outcome of ...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  On XX/XX/18 an item showed up on my credit rep...
# 9  Saw on my credit report that there is a collec...
#
#                              Company public response  \
# 0   Company chooses not to provide a public response
# 1                                                NaN
# 2                                                NaN
# 3   Company chooses not to provide a public response
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Company has responded to the consumer and the ...
# 8  Company has responded to the consumer and the ...
# 9  Company believes complaint caused principally ...
#
#                                   Company State ZIP code            Tags  \
# 0     Experian Information Solutions Inc.    NJ    08872             NaN
# 1                           EQUIFAX, INC.    NY    10801             NaN
# 2    SANTANDER CONSUMER USA HOLDINGS INC.    GA    300XX   Servicemember
# 3                   WELLS FARGO & COMPANY    CA    94526             NaN
# 4                           DISCOVER BANK    NV    891XX             NaN
# 5   BANK OF AMERICA, NATIONAL ASSOCIATION    PA    175XX             NaN
# 6   BANK OF AMERICA, NATIONAL ASSOCIATION    MD    210XX             NaN
# 7                     SYNCHRONY FINANCIAL    CA    92595   Servicemember
# 8  TRANSUNION INTERMEDIATE HOLDINGS, INC.    VA    245XX             NaN
# 9                    Cascade Capital, LLC    FL    334XX  Older American
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0       Consent not provided           Web           08/09/2015
# 1       Consent not provided           Web           01/30/2019
# 2                        NaN           Web           10/13/2019
# 3       Consent not provided           Web           08/19/2015
# 4           Consent provided           Web           03/04/2016
# 5                        NaN      Referral           03/19/2013
# 6                        NaN           Web           12/22/2011
# 7       Consent not provided           Web           10/24/2018
# 8           Consent provided           Web           03/03/2018
# 9           Consent provided           Web           01/18/2019
#
#       Company response to consumer Timely response? Consumer disputed?  \
# 0  Closed with non-monetary relief              Yes                 No
# 1  Closed with non-monetary relief              Yes                NaN
# 2          Closed with explanation              Yes                NaN
# 3          Closed with explanation              Yes                 No
# 4          Closed with explanation              Yes                Yes
# 5          Closed with explanation              Yes                 No
# 6            Closed without relief              Yes                 No
# 7          Closed with explanation              Yes                NaN
# 8          Closed with explanation              Yes                NaN
# 9          Closed with explanation              Yes                NaN
#
#    Complaint ID
# 0       1509954
# 1       3136759
# 2       3404213
# 3       1527601
# 4       1816726
# 5        358304
# 6          7362
# 7       3054861
# 8       2831821
# 9       3114357

# %%
df.count()
# Out:
# Date received                   1420970
# Product                         1420970
# Sub-product                     1185804
# Issue                           1420970
# Sub-issue                        872404
# Consumer complaint narrative     456275
# Company public response          521617
# Company                         1420970
# State                           1397688
# ZIP code                        1290110
# Tags                             193935
# Consumer consent provided?       817198
# Submitted via                   1420970
# Date sent to company            1420970
# Company response to consumer    1420969
# Timely response?                1420970
# Consumer disputed?               768484
# Complaint ID                    1420970
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
df['Company response to consumer'].unique()
# Out:
# array(['Closed with non-monetary relief', 'Closed with explanation',
#        'Closed without relief', 'Closed with monetary relief', 'Closed',
#        'In progress', 'Untimely response', 'Closed with relief', nan],
#       dtype=object)

# %%
df['Consumer disputed?'].unique()
# Out:
# array(['No', nan, 'Yes'], dtype=object)

# %%
df['Issue'].unique()
# Out:
# array(['Incorrect information on credit report',
#        "Problem with a credit reporting company's investigation into an existing problem",
#        'Attempts to collect debt not owed',
#        'Loan servicing, payments, escrow account', 'Billing disputes',
#        'Loan modification,collection,foreclosure',
#        'Incorrect information on your report',
#        'Improper use of your report',
#        'Account opening, closing, or management',
#        'Problem with a purchase shown on your statement',
#        'Identity theft / Fraud / Embezzlement', "Can't contact lender",
#        'False statements or representation',
#        'Problems when you are unable to pay',
#        'Disclosure verification of debt', 'Struggling to pay your loan',
#        'Deposits and withdrawals',
#        "Cont'd attempts collect debt not owed",
#        'Trouble during payment process', 'Unexpected or other fees',
#        'Problem with a lender or other company charging your account',
#        'Other transaction issues', 'Written notification about debt',
#        'Problem when making payments',
#        'Credit card protection / Debt protection',
#        'Credit monitoring or identity protection', 'Closing an account',
#        'Managing the loan or lease', 'Other transaction problem',
#        'Communication tactics', 'Dealing with my lender or servicer',
#        'Other', 'APR or interest rate', 'Closing your account',
#        'Dealing with your lender or servicer',
#        'Improper use of my credit report', 'Struggling to pay mortgage',
#        'Rewards', 'Managing an account', 'Settlement process and costs',
#        'Advertising and marketing, including promotional offers',
#        'Took or threatened to take negative or legal action',
#        'Repaying your loan', 'Unable to get credit report/credit score',
#        "Can't repay my loan", 'Application, originator, mortgage broker',
#        'Transaction issue', "Credit reporting company's investigation",
#        'Unauthorized transactions/trans. issues',
#        'Improper contact or sharing of info',
#        'Closing/Cancelling account', 'Collection practices',
#        'Applying for a mortgage or refinancing an existing mortgage',
#        'Fees or interest',
#        'Problem with fraud alerts or security freezes',
#        'Customer service / Customer relations', 'Getting a credit card',
#        'Problems caused by my funds being low',
#        'Unsolicited issuance of credit card',
#        'Credit decision / Underwriting',
#        'Taking/threatening an illegal action', 'Closing on a mortgage',
#        'Making/receiving payments, sending money',
#        'Account terms and changes', 'Other fee', 'Sale of account',
#        'Delinquent account', 'Payoff process',
#        'Other features, terms, or problems', 'Fraud or scam',
#        'Struggling to repay your loan',
#        "Charged fees or interest you didn't expect", 'Late fee',
#        'Collection debt dispute', 'Using a debit or ATM card',
#        'Applying for a mortgage', 'Money was not available when promised',
#        'Advertising and marketing', 'Problem with a purchase or transfer',
#        'Confusing or misleading advertising or marketing',
#        'Customer service/Customer relations',
#        'Unable to get your credit report or credit score',
#        'Managing, opening, or closing account', 'Adding money',
#        'Application processing delay',
#        "Charged fees or interest I didn't expect",
#        'Payment to acct not credited', 'Other service problem',
#        'Problem with the payoff process at the end of the loan',
#        'Wrong amount charged or received',
#        'Unauthorized transactions or other transaction problem',
#        'Problem caused by your funds being low',
#        "Can't stop charges to bank account",
#        'Managing, opening, or closing your mobile wallet account',
#        'Shopping for a loan or lease', 'Balance transfer fee',
#        'Opening an account', 'Credit determination',
#        'Threatened to contact someone or share information improperly',
#        'Credit line increase/decrease', 'Problem with customer service',
#        'Taking out the loan or lease', 'Balance transfer',
#        'Money was taken from your bank account on the wrong day or for the wrong amount',
#        'Vehicle was repossessed or sold the vehicle',
#        'Trouble using the card',
#        'Credit monitoring or identity theft protection services',
#        "Can't contact lender or servicer", 'Credit reporting', 'Privacy',
#        'Trouble using your card', 'Billing statement',
#        "Can't stop withdrawals from your bank account", 'Overlimit fee',
#        "Problem with a company's investigation into an existing issue",
#        'Confusing or missing disclosures',
#        'Identity theft protection or other monitoring services',
#        'Incorrect exchange rate', 'Forbearance / Workout plans',
#        'Charged bank acct wrong day or amt',
#        "Received a loan I didn't apply for",
#        'Problems at the end of the loan or lease', 'Other service issues',
#        'Getting a loan or lease', 'Bankruptcy', 'Cash advance',
#        'Struggling to pay your bill', 'Managing the line of credit',
#        'Getting a loan', 'Getting a line of credit', 'Arbitration',
#        'Problem adding money', 'Lost or stolen check',
#        'Vehicle was damaged or destroyed the vehicle',
#        'Incorrect/missing disclosures or info', 'Getting the loan',
#        'Problem with additional add-on products or services', 'Fees',
#        'Problem with cash advance', 'Cash advance fee',
#        'Convenience checks', 'Advertising',
#        "Received a loan you didn't apply for",
#        'Advertising, marketing or disclosures',
#        'Applied for loan/did not receive money',
#        'Lender repossessed or sold the vehicle',
#        'Shopping for a line of credit',
#        'Problem getting a card or closing an account',
#        'Lost or stolen money order',
#        "Was approved for a loan, but didn't receive the money",
#        'Disclosures', 'Excessive fees', 'Credit limit changed',
#        'Unexpected/Other fees', 'Lender sold the property',
#        "Loan payment wasn't credited to your account",
#        'Overdraft, savings or rewards features',
#        'Problem with an overdraft',
#        'Problem with credit report or credit score',
#        'Lender damaged or destroyed property',
#        "Was approved for a loan, but didn't receive money",
#        'Overdraft, savings, or rewards features',
#        'Problem with overdraft', 'Property was sold',
#        'Lender damaged or destroyed vehicle',
#        'Property was damaged or destroyed property'], dtype=object)

# %%
df['Timely response?'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Company public response'].unique()
# Out:
# array(['Company chooses not to provide a public response', nan,
#        'Company has responded to the consumer and the CFPB and chooses not to provide a public response',
#        'Company believes complaint caused principally by actions of third party outside the control or direction of the company',
#        'Company believes it acted appropriately as authorized by contract or law',
#        'Company believes complaint is the result of an isolated error',
#        'Company disputes the facts presented in the complaint',
#        'Company believes the complaint is the result of a misunderstanding',
#        "Company can't verify or dispute the facts in the complaint",
#        'Company believes complaint represents an opportunity for improvement to better serve consumers',
#        'Company believes complaint relates to a discontinued policy or procedure'],
#       dtype=object)

# %% [markdown]
# ### Simple Scoring Function
# After the data is profiled, a simple evaluation algorithm using 3 fields is developed.

# %%
# Weights for "Company Response"
response_weights = {
    'Closed with monetary relief': 3,
    'Closed with non-monetary relief': 2,
    'Closed with relief': 2,
    'Closed with explanation': 1,
    'Closed without relief': -1,
    'Closed': -1,
    'In progress': 0,
    'Untimely response': -2,
    'N/A': 0,
    'nan': 0,
    None: 0
}

# Weights for "Consumer disputed?"
disputed_weights = {
    'No': 2,
    'Yes': -2,
    'N/A': 0,
    'nan': 0,
    None: 0
}

# Weights for "Timely response?"
timely_weights = {
    'No': -2,
    'Yes': 2,
    'N/A': 0,
    'nan': 0,
    None: 0
}


def evalutate_quantitative(row)->int:
    """
    Provides score for a single record of bank consumer data looking only at the "Quantitative" fields

    :param row: a single complaint record
    :return: int score
    """
    score = 0
    score = score + timely_weights[str(row['Timely response?'])]
    score = score + disputed_weights[str(row['Consumer disputed?'])]
    score = score + response_weights[str(row['Company response to consumer'])]

    return score

# %% [markdown]
# ### Apply Scoring Function
# Each record now has a score assoviated with it. Positive for good, negative for bad.

# %%
begin = time.time()
df['score']=df.apply(lambda row: evalutate_quantitative(row), axis=1)
print(f"Elapsed: {round(time.time()-begin, 2)} sec")
# Out:
# Elapsed: 35.29 sec

# %%
df.head(10)
# Out:
#   Date received                                            Product  \
# 0    08/09/2015                                   Credit reporting
# 1    01/29/2019  Credit reporting, credit repair services, or o...
# 2    10/13/2019                                    Debt collection
# 3    08/19/2015                                           Mortgage
# 4    03/04/2016                                        Credit card
# 5    03/18/2013                                           Mortgage
# 6    12/21/2011                                           Mortgage
# 7    10/24/2018  Credit reporting, credit repair services, or o...
# 8    03/03/2018  Credit reporting, credit repair services, or o...
# 9    01/02/2019                                    Debt collection
#
#                               Sub-product  \
# 0                                     NaN
# 1                        Credit reporting
# 2                           I do not know
# 3  Conventional adjustable mortgage (ARM)
# 4                                     NaN
# 5                          Other mortgage
# 6             Conventional fixed mortgage
# 7                        Credit reporting
# 8                        Credit reporting
# 9                           I do not know
#
#                                                Issue  \
# 0             Incorrect information on credit report
# 1  Problem with a credit reporting company's inve...
# 2                  Attempts to collect debt not owed
# 3           Loan servicing, payments, escrow account
# 4                                   Billing disputes
# 5           Loan modification,collection,foreclosure
# 6           Loan modification,collection,foreclosure
# 7               Incorrect information on your report
# 8               Incorrect information on your report
# 9                  Attempts to collect debt not owed
#
#                                            Sub-issue  \
# 0                            Information is not mine
# 1  Was not notified of investigation status or re...
# 2                  Debt was result of identity theft
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                           Account status incorrect
# 8                Information belongs to someone else
# 9                  Debt was result of identity theft
#
#                         Consumer complaint narrative  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  I am dissatisfied with the current outcome of ...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  On XX/XX/18 an item showed up on my credit rep...
# 9  Saw on my credit report that there is a collec...
#
#                              Company public response  \
# 0   Company chooses not to provide a public response
# 1                                                NaN
# 2                                                NaN
# 3   Company chooses not to provide a public response
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Company has responded to the consumer and the ...
# 8  Company has responded to the consumer and the ...
# 9  Company believes complaint caused principally ...
#
#                                   Company State ZIP code            Tags  \
# 0     Experian Information Solutions Inc.    NJ    08872             NaN
# 1                           EQUIFAX, INC.    NY    10801             NaN
# 2    SANTANDER CONSUMER USA HOLDINGS INC.    GA    300XX   Servicemember
# 3                   WELLS FARGO & COMPANY    CA    94526             NaN
# 4                           DISCOVER BANK    NV    891XX             NaN
# 5   BANK OF AMERICA, NATIONAL ASSOCIATION    PA    175XX             NaN
# 6   BANK OF AMERICA, NATIONAL ASSOCIATION    MD    210XX             NaN
# 7                     SYNCHRONY FINANCIAL    CA    92595   Servicemember
# 8  TRANSUNION INTERMEDIATE HOLDINGS, INC.    VA    245XX             NaN
# 9                    Cascade Capital, LLC    FL    334XX  Older American
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0       Consent not provided           Web           08/09/2015
# 1       Consent not provided           Web           01/30/2019
# 2                        NaN           Web           10/13/2019
# 3       Consent not provided           Web           08/19/2015
# 4           Consent provided           Web           03/04/2016
# 5                        NaN      Referral           03/19/2013
# 6                        NaN           Web           12/22/2011
# 7       Consent not provided           Web           10/24/2018
# 8           Consent provided           Web           03/03/2018
# 9           Consent provided           Web           01/18/2019
#
#       Company response to consumer Timely response? Consumer disputed?  \
# 0  Closed with non-monetary relief              Yes                 No
# 1  Closed with non-monetary relief              Yes                NaN
# 2          Closed with explanation              Yes                NaN
# 3          Closed with explanation              Yes                 No
# 4          Closed with explanation              Yes                Yes
# 5          Closed with explanation              Yes                 No
# 6            Closed without relief              Yes                 No
# 7          Closed with explanation              Yes                NaN
# 8          Closed with explanation              Yes                NaN
# 9          Closed with explanation              Yes                NaN
#
#    Complaint ID  score
# 0       1509954      6
# 1       3136759      4
# 2       3404213      3
# 3       1527601      5
# 4       1816726      1
# 5        358304      5
# 6          7362      3
# 7       3054861      3
# 8       2831821      3
# 9       3114357      3

# %% [markdown]
# ### Filter out companies with less than 30 records
# We cannot be confident in ratings for companies with not enough data.

# %%
begin = time.time()
df_filtered = df.groupby("Company").filter(lambda row: len(row)>30)
print(f"Elapsed: {round(time.time()-begin, 2)} sec")
# Out:
# Elapsed: 1.21 sec

# %%
df_filtered.count()
# Out:
# Date received                   1393817
# Product                         1393817
# Sub-product                     1159216
# Issue                           1393817
# Sub-issue                        853538
# Consumer complaint narrative     445067
# Company public response          512627
# Company                         1393817
# State                           1371097
# ZIP code                        1266374
# Tags                             189990
# Consumer consent provided?       799441
# Submitted via                   1393817
# Date sent to company            1393817
# Company response to consumer    1393816
# Timely response?                1393817
# Consumer disputed?               754170
# Complaint ID                    1393817
# score                           1393817
# dtype: int64

# %% [markdown]
# ### Aggregate the score for each company

# %%
df_company = df_filtered.groupby(["Company"]).agg({"score":"mean"})

# %% [markdown]
# #### Bottom 10 Companies

# %%
df_company.sort_values("score").head(10)
# Out:
#                                              score
# Company
# Walwick, Inc                             -3.437500
# Global Portfolio Recovery, LLC           -3.400000
# ALTERNATIVE DISPUTE RESOLUTIONS          -3.375000
# VANGUARD FUNDING LLC                     -3.184211
# Screening Reports Inc.                   -3.125000
# Mobiloans, LLC                           -2.738693
# Accelerated Receivables Management, Inc. -2.686567
# NAM National Arbitration and Mediation   -2.486842
# Ameritech Financial                      -2.416268
# Diversified Recovery Services Inc.       -2.090909

# %% [markdown]
# #### Top 10 Companies

# %%
df_company.sort_values("score", ascending=False).head(10)
# Out:
#                                                       score
# Company
# Express Aviation                                   6.518519
# Empowerment Ventures, LLC                          5.935089
# Oxford Law, LLC                                    5.344595
# Accounts Receivable Management, Inc (NJ) (Closed)  5.269231
# Turning Point Solutions LLC                        5.142857
# Allied Interstate LLC                              5.110692
# Media Collections, Inc                             5.103704
# Van Ru Credit Corporation                          5.059633
# The Affiliated Group, Inc                          5.030769
# Brelvis Consulting, LLC                            4.969697

# %% [markdown]
# ### Aggregate the score for each product

# %%
df_product = df_filtered.groupby(["Product"]).agg({"score":"mean"})

# %%
df_product.sort_values("score")
# Out:
#                                                        score
# Product
# Virtual currency                                    2.444444
# Payday loan, title loan, or personal loan           2.861279
# Vehicle loan or lease                               3.062842
# Credit reporting, credit repair services, or ot...  3.132761
# Money transfer, virtual currency, or money service  3.145225
# Credit card or prepaid card                         3.412896
# Checking or savings account                         3.421037
# Debt collection                                     3.595150
# Mortgage                                            3.792152
# Student loan                                        3.796980
# Payday loan                                         4.004228
# Other financial service                             4.102273
# Consumer Loan                                       4.158200
# Bank account or service                             4.549917
# Credit card                                         4.574005
# Money transfers                                     4.576021
# Credit reporting                                    4.643703
# Prepaid card                                        5.122009
